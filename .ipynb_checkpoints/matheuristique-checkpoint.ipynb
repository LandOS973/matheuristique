# %%
import fitness
import glouton
import random_schedule
import local_search_descente
import matplotlib.pyplot as plt
import time

# Fonction d'affichage pour la planification
import matplotlib.pyplot as plt
import numpy as np

# %%
# Fonction d'affichage pour la planification
def print_schedule(schedule, filename='schedule.png'):
    num_weeks = len(schedule)
    num_periods = len(schedule[0]) if num_weeks > 0 else 0

    # Créer une matrice pour représenter le tableau
    schedule_matrix = np.full((num_weeks, num_periods), '', dtype=object)

    # Remplir la matrice avec les équipes ou une indication de cellule vide
    for week in range(num_weeks):
        for period in range(num_periods):
            match = schedule[week][period]
            if match:
                schedule_matrix[week, period] = f"{match[0]} vs {match[1]}"
            else:
                schedule_matrix[week, period] = "(vide)"

    # Créer une figure et des axes
    fig, ax = plt.subplots(figsize=(10, 6))

    # Afficher le tableau avec Matplotlib
    ax.axis('tight')
    ax.axis('off')

    # Créer un tableau à partir de la matrice
    table = ax.table(cellText=schedule_matrix,
                     colLabels=[f"Période {i+1}" for i in range(num_periods)],
                     rowLabels=[f"Semaine {i+1}" for i in range(num_weeks)],
                     cellLoc='center',
                     loc='center')

    # Personnaliser l'apparence du tableau
    table.auto_set_font_size(False)
    table.set_fontsize(12)
    table.scale(1, 1.5)  # Ajustez la taille des cellules si nécessaire

    # Sauvegarder l'image du tableau
    plt.savefig(filename, bbox_inches='tight')
    plt.show()  # Afficher le tableau

import time  # Pour mesurer le temps d'exécution

def mean_score(algo='glouton'):
    # Nombre d'itérations
    it = 200
    sum_fitness = 0  # Pour stocker la somme des scores de fitness
    total_time = 0   # Pour stocker la somme des temps d'exécution

    print("Calcul de la moyenne pour " + algo + " sur " + str(it) + " itérations")

    for i in range(it):
        start_time = time.time()  # Démarre le chronomètre pour l'itération

        if algo == 'glouton':
            schedule = glouton.round_robin_schedule(8)
        elif algo == 'random':
            schedule = random_schedule.random_round_robin_schedule(8)
        elif algo == 'local_search_random':
            schedule = local_search_descente.local_search(random_schedule.random_round_robin_schedule(8), 8, max_iterations=600, verbose=False)[0]
        elif algo == 'local_search_glouton':
            schedule = local_search_descente.local_search(glouton.round_robin_schedule(8), 8, max_iterations=600, verbose=False)[0]

        # Calculer le score de fitness
        sum_fitness += fitness.evaluate_schedule(schedule, 8, False)

        end_time = time.time()  # Arrête le chronomètre
        total_time += (end_time - start_time)  # Ajoute le temps écoulé à la somme totale

    # Moyenne des scores et des temps
    mean_fitness = sum_fitness / it
    mean_time = total_time / it

    print(f"Temps moyen d'exécution pour {algo}: {mean_time:.5f} secondes")
    print(f"Score moyen de fitness pour {algo}: {mean_fitness:.5f}")

    return mean_fitness, mean_time

# %%
    num_teams = 8
    
    # glouton 
    scheduleGlouton = glouton.round_robin_schedule(num_teams)
    penaltyGlouton = fitness.evaluate_schedule(scheduleGlouton, num_teams, False)
    print("\n")
    print(f"GLOUTON : Score de la planification (pénalités totales): {penaltyGlouton}")
    print_schedule(scheduleGlouton)
# Out:
# GLOUTON : Score de la planification (pénalités totales): 640

# %%
    # random
    scheduleRandom = random_schedule.random_round_robin_schedule(num_teams)
    penaltyRandom = fitness.evaluate_schedule(scheduleRandom, num_teams, False)
    print("\n")
    print(f"RANDOM : Score de la planification (pénalités totales): {penaltyRandom}")
    print_schedule(scheduleRandom)
# Out:
# RANDOM : Score de la planification (pénalités totales): 519

# %%
    # recherche locale
    scheduleLocal, penaltyLocal, penalty_history = local_search_descente.local_search(scheduleRandom, num_teams, max_iterations=600, verbose=False)
    print("\n")
    print(f"RECHERCHE LOCALE : Score de la planification (pénalités totales): {penaltyLocal}")
    print_schedule(scheduleLocal)
    # Pour tracer les pénalités
# Out:
# Iteration 0: Amélioration trouvée avec une pénalité de 504
# Changeant le match 1, 3 avec le match 3, 3
# Iteration 2: Amélioration trouvée avec une pénalité de 484
# Changeant l'équipe à domicile pour le match 3, 1
# Iteration 5: Amélioration trouvée avec une pénalité de 467
# Changeant le match 5, 1 avec le match 7, 2
# Iteration 6: Amélioration trouvée avec une pénalité de 467
# Changeant le match 5, 3 avec le match 6, 4
# Iteration 7: Amélioration trouvée avec une pénalité de 445
# Changeant l'équipe à domicile pour le match 4, 1
# Iteration 8: Amélioration trouvée avec une pénalité de 445
# Changeant le match 6, 3 avec le match 6, 1
# Iteration 9: Amélioration trouvée avec une pénalité de 445
# Changeant le match 6, 2 avec le match 6, 2
# Iteration 11: Amélioration trouvée avec une pénalité de 420
# Changeant l'équipe à domicile pour le match 2, 4
# Iteration 12: Amélioration trouvée avec une pénalité de 418
# Changeant le match 5, 4 avec le match 5, 3
# Iteration 13: Amélioration trouvée avec une pénalité de 408
# Changeant le match 3, 4 avec le match 2, 4
# Iteration 15: Amélioration trouvée avec une pénalité de 408
# Changeant le match 4, 3 avec le match 3, 3
# Iteration 18: Amélioration trouvée avec une pénalité de 390
# Changeant l'équipe à domicile pour le match 1, 1
# Iteration 19: Amélioration trouvée avec une pénalité de 390
# Changeant le match 2, 3 avec le match 5, 3
# Iteration 21: Amélioration trouvée avec une pénalité de 382
# Changeant l'équipe à domicile pour le match 6, 3
# Iteration 23: Amélioration trouvée avec une pénalité de 362
# Changeant l'équipe à domicile pour le match 7, 4
# Iteration 24: Amélioration trouvée avec une pénalité de 362
# Changeant le match 1, 3 avec le match 1, 4
# Iteration 26: Amélioration trouvée avec une pénalité de 352
# Changeant le match 7, 3 avec le match 6, 3
# Iteration 27: Amélioration trouvée avec une pénalité de 352
# Changeant le match 1, 1 avec le match 5, 2
# Iteration 28: Amélioration trouvée avec une pénalité de 330
# Changeant l'équipe à domicile pour le match 1, 3
# Iteration 32: Amélioration trouvée avec une pénalité de 330
# Changeant le match 7, 2 avec le match 7, 3
# Iteration 34: Amélioration trouvée avec une pénalité de 330
# Changeant l'équipe à domicile pour le match 4, 4
# Iteration 36: Amélioration trouvée avec une pénalité de 330
# Changeant le match 3, 2 avec le match 2, 2
# Iteration 37: Amélioration trouvée avec une pénalité de 328
# Changeant le match 3, 1 avec le match 6, 2
# Iteration 38: Amélioration trouvée avec une pénalité de 325
# Changeant l'équipe à domicile pour le match 6, 2
# Iteration 40: Amélioration trouvée avec une pénalité de 325
# Changeant le match 6, 4 avec le match 6, 4
# Iteration 41: Amélioration trouvée avec une pénalité de 325
# Changeant le match 2, 4 avec le match 4, 4
# Iteration 43: Amélioration trouvée avec une pénalité de 325
# Changeant le match 5, 3 avec le match 2, 3
# Iteration 44: Amélioration trouvée avec une pénalité de 305
# Changeant l'équipe à domicile pour le match 3, 1
# Iteration 46: Amélioration trouvée avec une pénalité de 293
# Changeant l'équipe à domicile pour le match 6, 4
# Iteration 47: Amélioration trouvée avec une pénalité de 256
# Changeant l'équipe à domicile pour le match 4, 4
# Iteration 50: Amélioration trouvée avec une pénalité de 254
# Changeant l'équipe à domicile pour le match 5, 4
# Iteration 52: Amélioration trouvée avec une pénalité de 219
# Changeant l'équipe à domicile pour le match 2, 1
# Iteration 54: Amélioration trouvée avec une pénalité de 216
# Changeant l'équipe à domicile pour le match 2, 3
# Iteration 57: Amélioration trouvée avec une pénalité de 196
# Changeant l'équipe à domicile pour le match 4, 3
# Iteration 60: Amélioration trouvée avec une pénalité de 196
# Changeant le match 3, 4 avec le match 3, 2
# Iteration 61: Amélioration trouvée avec une pénalité de 196
# Changeant le match 2, 4 avec le match 2, 1
# Iteration 62: Amélioration trouvée avec une pénalité de 166
# Changeant l'équipe à domicile pour le match 1, 3
# Iteration 66: Amélioration trouvée avec une pénalité de 164
# Changeant le match 5, 3 avec le match 2, 4
# Iteration 67: Amélioration trouvée avec une pénalité de 159
# Changeant le match 5, 1 avec le match 3, 3
# Iteration 69: Amélioration trouvée avec une pénalité de 159
# Changeant le match 2, 1 avec le match 3, 3
# Iteration 70: Amélioration trouvée avec une pénalité de 155
# Changeant le match 3, 4 avec le match 3, 3
# Iteration 72: Amélioration trouvée avec une pénalité de 147
# Changeant le match 7, 2 avec le match 5, 3
# Iteration 76: Amélioration trouvée avec une pénalité de 145
# Changeant l'équipe à domicile pour le match 3, 2
# Iteration 80: Amélioration trouvée avec une pénalité de 144
# Changeant le match 6, 4 avec le match 4, 1
# Iteration 81: Amélioration trouvée avec une pénalité de 137
# Changeant le match 4, 1 avec le match 6, 2
# Iteration 83: Amélioration trouvée avec une pénalité de 137
# Changeant le match 1, 2 avec le match 1, 1
# Iteration 90: Amélioration trouvée avec une pénalité de 137
# Changeant le match 4, 1 avec le match 2, 2
# Iteration 99: Amélioration trouvée avec une pénalité de 137
# Changeant le match 6, 3 avec le match 6, 2
# Iteration 101: Amélioration trouvée avec une pénalité de 137
# Changeant le match 6, 3 avec le match 6, 3
# Iteration 113: Amélioration trouvée avec une pénalité de 137
# Changeant le match 5, 4 avec le match 2, 3
# Iteration 137: Amélioration trouvée avec une pénalité de 134
# Changeant le match 3, 4 avec le match 5, 2
# Iteration 139: Amélioration trouvée avec une pénalité de 131
# Changeant l'équipe à domicile pour le match 2, 1
# Iteration 143: Amélioration trouvée avec une pénalité de 131
# Changeant le match 7, 3 avec le match 7, 3
# Iteration 147: Amélioration trouvée avec une pénalité de 131
# Changeant le match 5, 1 avec le match 5, 3
# Iteration 150: Amélioration trouvée avec une pénalité de 129
# Changeant le match 5, 4 avec le match 5, 2
# Iteration 169: Amélioration trouvée avec une pénalité de 129
# Changeant le match 1, 4 avec le match 1, 4
# Iteration 176: Amélioration trouvée avec une pénalité de 129
# Changeant le match 5, 1 avec le match 5, 1
# Iteration 181: Amélioration trouvée avec une pénalité de 129
# Changeant le match 3, 3 avec le match 3, 3
# Iteration 187: Amélioration trouvée avec une pénalité de 129
# Changeant le match 1, 3 avec le match 1, 3
# Iteration 190: Amélioration trouvée avec une pénalité de 129
# Changeant le match 3, 3 avec le match 3, 3
# Iteration 194: Amélioration trouvée avec une pénalité de 129
# Changeant le match 1, 3 avec le match 1, 1
# Iteration 199: Amélioration trouvée avec une pénalité de 129
# Changeant le match 7, 4 avec le match 7, 4
# Iteration 211: Amélioration trouvée avec une pénalité de 129
# Changeant le match 4, 3 avec le match 4, 2
# Iteration 213: Amélioration trouvée avec une pénalité de 129
# Changeant le match 6, 1 avec le match 6, 3
# Iteration 220: Amélioration trouvée avec une pénalité de 111
# Changeant l'équipe à domicile pour le match 5, 1
# Iteration 221: Amélioration trouvée avec une pénalité de 111
# Changeant le match 5, 4 avec le match 5, 4
# Iteration 223: Amélioration trouvée avec une pénalité de 89
# Changeant l'équipe à domicile pour le match 2, 1
# Iteration 228: Amélioration trouvée avec une pénalité de 89
# Changeant le match 3, 2 avec le match 2, 1
# Iteration 238: Amélioration trouvée avec une pénalité de 89
# Changeant le match 1, 4 avec le match 1, 4
# Iteration 246: Amélioration trouvée avec une pénalité de 89
# Changeant le match 5, 3 avec le match 1, 4
# Iteration 251: Amélioration trouvée avec une pénalité de 89
# Changeant l'équipe à domicile pour le match 1, 4
# Iteration 252: Amélioration trouvée avec une pénalité de 89
# Changeant le match 4, 4 avec le match 4, 2
# Iteration 253: Amélioration trouvée avec une pénalité de 89
# Changeant le match 6, 2 avec le match 2, 1
# Iteration 256: Amélioration trouvée avec une pénalité de 89
# Changeant l'équipe à domicile pour le match 1, 4
# Iteration 257: Amélioration trouvée avec une pénalité de 87
# Changeant le match 1, 1 avec le match 1, 3
# Iteration 264: Amélioration trouvée avec une pénalité de 87
# Changeant le match 6, 3 avec le match 6, 1
# Iteration 268: Amélioration trouvée avec une pénalité de 87
# Changeant le match 7, 3 avec le match 7, 2
# Iteration 272: Amélioration trouvée avec une pénalité de 87
# Changeant le match 2, 1 avec le match 2, 1
# Iteration 284: Amélioration trouvée avec une pénalité de 87
# Changeant le match 7, 1 avec le match 7, 1
# Iteration 302: Amélioration trouvée avec une pénalité de 87
# Changeant le match 5, 1 avec le match 5, 3
# Iteration 307: Amélioration trouvée avec une pénalité de 85
# Changeant l'équipe à domicile pour le match 5, 1
# Iteration 308: Amélioration trouvée avec une pénalité de 85
# Changeant le match 7, 3 avec le match 7, 3
# Iteration 311: Amélioration trouvée avec une pénalité de 85
# Changeant le match 7, 3 avec le match 7, 2
# Iteration 313: Amélioration trouvée avec une pénalité de 85
# Changeant le match 2, 4 avec le match 2, 3
# Iteration 316: Amélioration trouvée avec une pénalité de 85
# Changeant le match 5, 1 avec le match 1, 1
# Iteration 322: Amélioration trouvée avec une pénalité de 85
# Changeant le match 4, 4 avec le match 4, 4
# Iteration 323: Amélioration trouvée avec une pénalité de 85
# Changeant le match 4, 3 avec le match 4, 3
# Iteration 324: Amélioration trouvée avec une pénalité de 85
# Changeant le match 6, 3 avec le match 4, 1
# Iteration 336: Amélioration trouvée avec une pénalité de 83
# Changeant le match 1, 3 avec le match 3, 1
# Iteration 337: Amélioration trouvée avec une pénalité de 83
# Changeant le match 1, 3 avec le match 1, 4
# Iteration 342: Amélioration trouvée avec une pénalité de 83
# Changeant le match 4, 4 avec le match 3, 3
# Iteration 346: Amélioration trouvée avec une pénalité de 83
# Changeant le match 4, 2 avec le match 3, 2
# Iteration 348: Amélioration trouvée avec une pénalité de 83
# Changeant le match 6, 2 avec le match 1, 3
# Iteration 354: Amélioration trouvée avec une pénalité de 83
# Changeant le match 1, 1 avec le match 1, 2
# Iteration 368: Amélioration trouvée avec une pénalité de 83
# Changeant le match 1, 2 avec le match 1, 2
# Iteration 369: Amélioration trouvée avec une pénalité de 82
# Changeant le match 1, 4 avec le match 4, 2
# Iteration 370: Amélioration trouvée avec une pénalité de 82
# Changeant le match 7, 2 avec le match 7, 3
# Iteration 374: Amélioration trouvée avec une pénalité de 82
# Changeant le match 5, 3 avec le match 5, 3
# Iteration 387: Amélioration trouvée avec une pénalité de 80
# Changeant le match 6, 1 avec le match 6, 4
# Iteration 388: Amélioration trouvée avec une pénalité de 80
# Changeant le match 4, 4 avec le match 4, 4
# Iteration 394: Amélioration trouvée avec une pénalité de 80
# Changeant l'équipe à domicile pour le match 3, 2
# Iteration 397: Amélioration trouvée avec une pénalité de 80
# Changeant le match 5, 2 avec le match 5, 4
# Iteration 399: Amélioration trouvée avec une pénalité de 80
# Changeant le match 5, 1 avec le match 7, 3
# Iteration 404: Amélioration trouvée avec une pénalité de 80
# Changeant le match 6, 2 avec le match 6, 2
# Iteration 418: Amélioration trouvée avec une pénalité de 80
# Changeant le match 6, 2 avec le match 6, 2
# Iteration 428: Amélioration trouvée avec une pénalité de 80
# Changeant le match 6, 4 avec le match 6, 1
# Iteration 430: Amélioration trouvée avec une pénalité de 78
# Changeant le match 1, 2 avec le match 1, 1
# Iteration 437: Amélioration trouvée avec une pénalité de 78
# Changeant le match 6, 3 avec le match 7, 3
# Iteration 441: Amélioration trouvée avec une pénalité de 78
# Changeant le match 5, 2 avec le match 5, 1
# Iteration 445: Amélioration trouvée avec une pénalité de 68
# Changeant le match 7, 4 avec le match 6, 4
# Iteration 487: Amélioration trouvée avec une pénalité de 68
# Changeant le match 3, 1 avec le match 3, 3
# Iteration 494: Amélioration trouvée avec une pénalité de 68
# Changeant le match 6, 2 avec le match 6, 2
# Iteration 501: Amélioration trouvée avec une pénalité de 68
# Changeant le match 2, 3 avec le match 2, 3
# Iteration 506: Amélioration trouvée avec une pénalité de 63
# Changeant l'équipe à domicile pour le match 4, 2
# Iteration 520: Amélioration trouvée avec une pénalité de 63
# Changeant le match 6, 4 avec le match 6, 4
# Iteration 536: Amélioration trouvée avec une pénalité de 63
# Changeant le match 4, 3 avec le match 4, 4
# Iteration 547: Amélioration trouvée avec une pénalité de 63
# Changeant le match 6, 2 avec le match 1, 3
# Iteration 552: Amélioration trouvée avec une pénalité de 63
# Changeant le match 3, 4 avec le match 3, 4
# Iteration 575: Amélioration trouvée avec une pénalité de 41
# Changeant l'équipe à domicile pour le match 4, 1
# Iteration 583: Amélioration trouvée avec une pénalité de 41
# Changeant le match 6, 2 avec le match 6, 4
# Iteration 586: Amélioration trouvée avec une pénalité de 41
# Changeant le match 5, 3 avec le match 5, 3
# Recherche locale terminée après 600 itérations.
# Semaine 2, période 2: L'équipe 3 joue plus d'une fois cette semaine. Pénalité ajoutée de 5
# Semaine 3, période 1: L'équipe 2 joue plus d'une fois cette semaine. Pénalité ajoutée de 5
# Semaine 6, période 3: Le match entre 5 et 3 a déjà eu lieu. Pénalité ajoutée de 10
# Période 3: L'équipe 0 apparaît 3 fois dans cette période. Pénalité ajoutée de 2
# Période 3: L'équipe 3 apparaît 3 fois dans cette période. Pénalité ajoutée de 2
# Période 1: L'équipe 7 apparaît 3 fois dans cette période. Pénalité ajoutée de 2
# Les paires d'équipes suivantes ne se sont jamais rencontrées:
# Équipe 4 vs Équipe 5. Pénalité ajoutée de 15
#
#
# RECHERCHE LOCALE : Score de la planification (pénalités totales): 41

# %%
    iterations = [entry[0] for entry in penalty_history]
    penalties = [entry[1] for entry in penalty_history]
    
    plt.plot(iterations, penalties)
    plt.xlabel('Itérations')
    plt.ylabel('Pénalités')
    plt.title('Évolution des pénalités de la recherche locale a partir d\'un random')
    plt.show()

# %%
    # Comparaison des algorithmes
    mean_score('glouton')
    mean_score('random')
    mean_score('local_search_random')
    mean_score('local_search_glouton')
# Out:
# Calcul de la moyenne pour glouton sur 200 itérations
# Temps moyen d'exécution pour glouton: 0.00003 secondes
# Score moyen de fitness pour glouton: 640.00000
# Calcul de la moyenne pour random sur 200 itérations
# Temps moyen d'exécution pour random: 0.00005 secondes
# Score moyen de fitness pour random: 448.76000
# Calcul de la moyenne pour local_search_random sur 200 itérations
# Temps moyen d'exécution pour local_search_random: 0.06705 secondes
# Score moyen de fitness pour local_search_random: 51.73000
# Calcul de la moyenne pour local_search_glouton sur 200 itérations
